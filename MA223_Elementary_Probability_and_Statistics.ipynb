# %% [markdown]
# <a href="https://colab.research.google.com/github/sylvadon5/StatsLearning-Intro/blob/main/MA223_Elementary_Probability_and_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started!
#
# ## Welcome to MA223!!
#
# - The course is partitioned into eight modules.
# In each module, you will learn about specific statistical concepts, techniques, and interpretations.
# - Python labs are an important part of the course where you will learn to analyze large datasets.
# - By the end of this course, you should be able to:
#     1. perform efficient, effective, and adaptable data analysis using modern statistical programming languages such as Python and R.
#     2. interpret data analysis results appropriately.
#     3. Communicate data analysis results in writing and orally to non-technical statistical audiences.
# - Assignments in this course are as follows:
#     - Weekly homework - 20%
#     - Weekly quizzes/class activities - 10%
#     - Three tests - 20%
#     - Five mini projects - 30%
#     - Final exam - 20%
#
# ## Learning Resources
# - Required textbook
#  - Allan Bluman, Elementary Probability and Statistics, McGraw Hill, 2013.
# - Sumplementary Material
#  - Online Statistics Education: An Interactive Multimedia Course of Study, is available at http://onlinestatbook.com.
#  - OpenIntro Statistics (Link: https://www.openintro.org/book/os/).

# %% [markdown]
# # Module 1: Data and Data Collection
#
# ## Topics:
#  - Topic 1: Statistical Analysis
#  - Topic 2: Classifying Data
#  - Topic 3: Collecting Data
#  - Module 1 Lab
#  - Project 1 (Due: 8/15/22 on canvas)
#
# ## Topic 1: Statistical Analysis
#
# - The learning objectives for this Module are to:
#  - Distinguish between descriptive and inferential statistics.
#  - Distinguish between populations and samples.
#  - Distinguish between random and non-random sampling methods.
#  - Identify types of variables and data.
#  - Apply data collection techniques.
