# %% [markdown]
# <a href="https://colab.research.google.com/github/sylvadon5/StatsLearning-Intro/blob/main/Introduction_to_Software.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MA530: Statistical Learning
#
# <img src="https://www.kdnuggets.com/wp-content/uploads/intro-stat-learning-2nd-ed.jpg" width="200" height="150" alt="Computer Hope">
#
# <img src="https://miro.medium.com/max/1400/1*7oukapIBInsovpHkQB3QZg.jpeg" width="200" height="150" alt="Computer Hope">
#
# <img src="https://images.ctfassets.net/mrop88jh71hl/55rrbZfwMaURHZKAUc5oOW/9e5fe805eb03135b82e962e92169ce6d/python-programming-language.png" width="200" height="150" alt="Computer Hope">
#
#
# ## 1. Introduction to Google Colaboratory and Python
#
# ### 1.1 What is Colaboratory or Colab for short?
# Is a red product from Google Research. It allows anyone to write and execute python code through the browser, and is especially well suited to machine learning, data analysis and education.
#
# ### 1.2 How to run a code in Google Colab?
# It requires only two steps.
# 1. Sign into Google colab.
#     - To Sign in to google colab, you need to go to Google Colab url:
# https://colab.research.google.com
# 2. Create a new notebook.
# Once your are done, you can start writing your code.
# Sign in to google colab.
#
# ### 1.3 Short Video on Google Colaboratory (Colab)
# - Introduction to Google Colab: https://www.youtube.com/watch?v=g0xu9DA4gDw
# - Get started with Google Colab: https://www.youtube.com/watch?v=inN8seMm7UI
# - Google Colab Tutorial for Beginners: https://www.youtube.com/watch?v=RLYoEyIHL6A
#
# ### 1.4 Brief Introduction to Python
# - Python is a computer programming language often used to build websites and software, automate tasks, and conduct data analysis.
# - Python has become a staple in data science, allowing data analysts and other professionals to use the language to conduct complex statistical calculations, create data visualizations, build machine learning algorithms, manipulate and analyze data, and complete other data-related tasks.
# - Link to some tutorials on python: https://data-flair.training/blogs/python-tutorial/
#
# ## 2. Introduction to Statistical Learning
# - **Statistical learning** refers to a vast set of tools for understanding data.
#
# ### 2.1 Supervised and Unsupervised Learning
# - **Supervised:** Model built to predict a response from a set of predictors.
# - **Unsupervised:** Learn underlying structure of data. There is no prediction of response.

# %% [markdown]
# ## 2. Introduction to Statistical Learning
# - **Statistical learning** refers to a vast set of tools for understanding data.
#
# ### 2.1 Supervised and Unsupervised Learning
# - **Supervised:** Model built to predict a response from a set of predictors.
# - **Unsupervised:** Learn underlying structure of data. There is no prediction of response.
